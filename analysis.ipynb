# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
import sounddevice as sd

# %%
frames = np.load('test.npy')
frames[:5]
# Out:
# array([[  4,   7,   5, ...,   8,  12,   0],
#        [-15, -19,  -6, ...,   0,   5,   1],
#        [ -7,  -8,  -8, ...,   0,   3,   9],
#        [  8,   5,   4, ...,   8,  13,  16],
#        [ 15,   8,   1, ...,  22,  19,  11]], dtype=int16)

# %%
frames.shape
# Out:
# (1883, 512)

# %%
frame_num = 25

# %%
sd.play(frames[frame_num], 16000,blocking=True)

# %%
plt.plot(np.arange(0,512), frames[frame_num])
